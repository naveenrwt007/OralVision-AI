# %%
# !pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kagglehub in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (0.3.13)
# Requirement already satisfied: packaging in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: tqdm in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from requests->kagglehub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from requests->kagglehub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in C:\Users\Naveen Singh Rawat\AppData\Roaming\Python\Python313\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import kagglehub
import os

# %%
dataset_path = kagglehub.dataset_download(
    "zaidpy/oral-cancer-dataset"
)

print("Dataset Path:", dataset_path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.2).
# Dataset Path: C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2

# %%
os.listdir(dataset_path)
# Out:
# ['Oral Cancer', 'Oral cancer Dataset 2.0']

# %%
for root, dirs, files in os.walk(dataset_path):
    print(root)
    print("Images:", len(files))
# Out:
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2
# Images: 0
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral Cancer
# Images: 0
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral Cancer\Oral Cancer Dataset
# Images: 0
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral Cancer\Oral Cancer Dataset\CANCER
# Images: 500
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral Cancer\Oral Cancer Dataset\NON CANCER
# Images: 250
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral cancer Dataset 2.0
# Images: 0
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral cancer Dataset 2.0\OC Dataset kaggle new
# Images: 0
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral cancer Dataset 2.0\OC Dataset kaggle new\CANCER
# Images: 500
# C:\Users\Naveen Singh Rawat\.cache\kagglehub\datasets\zaidpy\oral-cancer-dataset\versions\2\Oral cancer Dataset 2.0\OC Dataset kaggle new\NON CANCER
# Images: 450
